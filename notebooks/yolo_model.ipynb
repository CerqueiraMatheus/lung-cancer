# %% [markdown]
# ## 0. Preparação do Ambiente

# %%
import locale
locale.getpreferredencoding()
# Out:
# 'UTF-8'

# %%
# Montagem do diretório virtual
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cópia do dataset para o workspace
# !cp -r /content/drive/MyDrive/lung-cancer-prediction/yolo_data_v2/ /content/lung

# %%
# Caminho do arquivo yaml (define o dataset)
yaml_path = "/content/lung/dataset.yaml"

# %%
# Instalação do YOLOv8
# %%capture
# !pip install ultralytics

# %% [markdown]
# # 1. Execução do modelo

# %%
# Import da biblioteca
from ultralytics import YOLO

# %%
# Modelo pré-treinado
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 13.4MB/s]

# %%
# Treinamento usando 300 épocas, imagens de 512x512, na GPU
results = model.train(data=yaml_path, epochs=300, imgsz=512, device=0, batch=-1)
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Cópia do dataset para o workspace
locale.getpreferredencoding = lambda: "UTF-8"
# !cp -r /content/runs/ /content/drive/MyDrive/lung-cancer-prediction/
